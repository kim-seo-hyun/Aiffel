# %% [markdown]
# # GoingDeeper 01. ResNet
#
# ## 프로젝트: ResNet Ablation Study
#
# ### lubric
#
# 1. ResNet-34, ResNet-50 모델 구현이 정상적으로 진행되었는가? 블록함수 구현이 제대로 진행되었으며 구현한 모델의 summary가 예상된 형태로 출력되었다.
# 2. 구현한 ResNet 모델을 활용하여 Image Classification 모델 훈련이 가능한가?cats_vs_dogs 데이터셋으로 학습시 몇 epoch동안 안정적으로 loss 감소가 진행 확인되었다.
# 3. Ablation Study 결과가 바른 포맷으로 제출되었는가? ResNet-34, ResNet-50 각각 plain모델과 residual모델을 동일한 epoch만큼 학습시켰을 때의 validation accuracy 기준으로 Ablation Study 결과표가 작성되었다.
#
# ### 학습 목표
#
# - 직접 ResNet 구현하기
# - 모델을 config에 따라서 변경 가능하도록 만들기
# - 직접 실험해서 성능 비교하기
#
# ### 🚩keyword
#
# ✔ CNN, ResNet, build

# %%
# TensorFlow and tf.keras
import tensorflow as tf
from tensorflow import keras

# Helper libraries
import numpy as np
import matplotlib.pyplot as plt

import tensorflow_datasets as tfds

# %%
import tensorflow as tf
import numpy as np

print(tf.__version__)
print(np.__version__)
# Out:
# 2.8.0
# 1.21.5
# 2.8.0
# 1.21.5

# %%
# Tensorflow가 활용할 GPU가 장착되어 있는지 확인해 봅니다.
tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# **data load**

# %%
(ds_train, ds_test), ds_info = tfds.load(
    'cats_vs_dogs',
    split=['train[:80%]', 'train[80%:]'], # test set 없어서 train 나누기
    as_supervised=True,
    shuffle_files=True,
    with_info=True,
)
# Out:
# Downloading and preparing dataset cats_vs_dogs/4.0.0 (download: 786.68 MiB, generated: Unknown size, total: 786.68 MiB) to /root/tensorflow_datasets/cats_vs_dogs/4.0.0...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# 0 examples [00:00, ? examples/s]
# WARNING:absl:1738 images were corrupted and were skipped
# Shuffling and writing examples to /root/tensorflow_datasets/cats_vs_dogs/4.0.0.incompleteYS96LW/cats_vs_dogs-train.tfrecord
#   0%|          | 0/23262 [00:00<?, ? examples/s]
# Dataset cats_vs_dogs downloaded and prepared to /root/tensorflow_datasets/cats_vs_dogs/4.0.0. Subsequent calls will reuse this data.

# %%
# Tensorflow 데이터셋을 로드하면 꼭 feature 정보를 확인해 보세요. 
print(ds_info.features)
# Out:
# FeaturesDict({
#     'image': Image(shape=(None, None, 3), dtype=tf.uint8),
#     'image/filename': Text(shape=(), dtype=tf.string),
#     'label': ClassLabel(shape=(), dtype=tf.int64, num_classes=2),
# })
# FeaturesDict({
#     'image': Image(shape=(None, None, 3), dtype=tf.uint8),
#     'image/filename': Text(shape=(), dtype=tf.string),
#     'label': ClassLabel(shape=(), dtype=tf.int64, num_classes=2),
# })

# %%
# 데이터의 개수도 확인해 봅시다. 
print(tf.data.experimental.cardinality(ds_train))
print(tf.data.experimental.cardinality(ds_test))
# Out:
# tf.Tensor(18610, shape=(), dtype=int64)
# tf.Tensor(4652, shape=(), dtype=int64)
# tf.Tensor(18610, shape=(), dtype=int64)
# tf.Tensor(4652, shape=(), dtype=int64)

# %%
ds_info.features["label"].num_classes
# Out:
# 2
# 2

# %%
ds_info.features["label"].names
# Out:
# ['cat', 'dog']
# ['cat', 'dog']

# %%
fig = tfds.show_examples(ds_train, ds_info)

# %%
fig = tfds.show_examples(ds_test, ds_info)

# %% [markdown]
# **normalize**

# %%
def normalize_and_resize_img(image, label):
    """Normalizes images: `uint8` -> `float32`."""
    image = tf.image.resize(image, (224,224))
    image = tf.cast(image, tf.float32) / 255.
    return image, label

# %%
def apply_normalize_on_dataset(ds, is_test=False, batch_size=16):
    ds = ds.map(
        normalize_and_resize_img, 
        num_parallel_calls=1
    )
    ds = ds.batch(batch_size)
    if not is_test:
        ds = ds.repeat()
        ds = ds.shuffle(200)
    ds = ds.prefetch(tf.data.experimental.AUTOTUNE)
    return ds

# %% [markdown]
# **1) ResNet 기본 블록 구성하기**
#
# ResNet-34와 ResNet-50은 모두 conv block이라고 불리는 블록 구조를 각각 3, 4, 6, 3개씩 반복해서 쌓은 형태라는 공통점을 가지고 있습니다. 그러나 ResNet-34와 ResNet-50의 블록 내부 구성은 약간 다릅니다. ResNet-34의 경우 Block은 3x3 kernel인 Convolution layer로만 구성되어있지만, ResNet-50은 1x1 Convolution이 앞뒤로 붙어 더 많은 레이어를 한 블록 내에 가지게 됩니다.

# %%
def conv_block(input_layer, 
               channel, 
               kernel_size, 
               strides=1, 
               activation='relu'):
    
    x = keras.layers.Conv2D(filters=channel,
                            kernel_size=kernel_size,
                            kernel_initializer='he_normal',
                            kernel_regularizer=keras.regularizers.l2(1e-4),
                            padding='same',
                            strides=strides
                           )(input_layer)
    
    x = keras.layers.BatchNormalization()(x)
    
    if activation:
        x = keras.layers.Activation(activation)(x)
    
    return x

# %%
def build_resnet_block(input_layer, 
                       num_cnn=3, 
                       channel=64, 
                       block_num=0, 
                       is_50=True): # is_50 : resnet 50을 사용할지 안할지를 정하는 bool 변수
    
    x = input_layer
    
    # ResNet-50
    if is_50:
        for i in range(num_cnn):
            if i == 0:
                shortcut = conv_block(x, channel*4, (1,1), strides=2, activation=None)
                x = conv_block(x, channel, (1,1), strides=2)
                x = conv_block(x, channel, (3,3))
                x = conv_block(x, channel*4, (1,1), activation=None)
            else:
                shortcut = x
                x = conv_block(x, channel, (1,1))
                x = conv_block(x, channel, (3,3))
                x = conv_block(x, channel*4, (1,1), activation=None)
            
            x = keras.layers.Add()([x, shortcut])
            x = keras.layers.Activation('relu')(x)
    
    # ResNet-34
    else:
        for i in range(num_cnn):
            if block_num > 0 and i == 0:
                shortcut = conv_block(x, channel, (1,1), strides=2, activation=None)
                x = conv_block(x, channel, (3,3), strides=2)
                x = conv_block(x, channel, (3,3), activation=None)
            else:
                shortcut = x
                x = conv_block(x, channel, (3,3))
                x = conv_block(x, channel, (3,3), activation=None)
            
            x = keras.layers.Add()([x, shortcut])
            x = keras.layers.Activation('relu')(x)
    

    return x

# %% [markdown]
# **2) ResNet-34, ResNet-50 Complete Model**

# %%
def build_resnet(input_shape=(32,32,3),
                 num_cnn_list=[3,4,6,3],
                 channel_list=[64,128,256,512],
                 num_classes=10, 
                 is_50=True, 
                 activation='softmax',
                 name='ResNet_50'):
    
    assert len(num_cnn_list) == len(channel_list) # 모델을 만들기 전에 config list들이 같은 길이인지 확인합니다.
    
    input_layer = keras.layers.Input(shape=input_shape)  # input layer를 만들어둡니다.
    
    # first layer
    x = conv_block(input_layer, 64, (7,7), strides=2)
    x = keras.layers.MaxPool2D(pool_size=(2,2), strides=2)(x)
    
    # config list들의 길이만큼 반복해서 Residual block 블록을 생성합니다.
    for block_num, (num_cnn, channel) in enumerate(zip(num_cnn_list, channel_list)):
        x = build_resnet_block(x, 
                               num_cnn=num_cnn, 
                               channel=channel, 
                               block_num=block_num, 
                               is_50=is_50)
        
    x = keras.layers.GlobalAveragePooling2D()(x)
    x = keras.layers.Dense(num_classes, 
                           activation=activation, 
                           kernel_initializer='he_normal'
                          )(x)
    
    model = keras.Model(inputs=input_layer, outputs=x, name=name)
    
    return model

# %% [markdown]
# **ResNet-34**

# %%
resnet_34 = build_resnet(input_shape=(32, 32,3), is_50=False)
resnet_34.summary()
# Out:
# Model: "ResNet_50"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 32, 32, 3)]  0           []
#
#  conv2d (Conv2D)                (None, 16, 16, 64)   9472        ['input_1[0][0]']
#
#  batch_normalization (BatchNorm  (None, 16, 16, 64)  256         ['conv2d[0][0]']
#  alization)
#
#  activation (Activation)        (None, 16, 16, 64)   0           ['batch_normalization[0][0]']
#
#  max_pooling2d (MaxPooling2D)   (None, 8, 8, 64)     0           ['activation[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 8, 8, 64)     36928       ['max_pooling2d[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 8, 8, 64)    256         ['conv2d_1[0][0]']
#  rmalization)
#
#  activation_1 (Activation)      (None, 8, 8, 64)     0           ['batch_normalization_1[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 8, 8, 64)     36928       ['activation_1[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 8, 8, 64)    256         ['conv2d_2[0][0]']
#  rmalization)
#
#  add (Add)                      (None, 8, 8, 64)     0           ['batch_normalization_2[0][0]',
#                                                                   'max_pooling2d[0][0]']
#
#  activation_2 (Activation)      (None, 8, 8, 64)     0           ['add[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 8, 8, 64)     36928       ['activation_2[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 8, 8, 64)    256         ['conv2d_3[0][0]']
#  rmalization)
#
#  activation_3 (Activation)      (None, 8, 8, 64)     0           ['batch_normalization_3[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 8, 8, 64)     36928       ['activation_3[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 8, 8, 64)    256         ['conv2d_4[0][0]']
#  rmalization)
#
#  add_1 (Add)                    (None, 8, 8, 64)     0           ['batch_normalization_4[0][0]',
#                                                                   'activation_2[0][0]']
#
#  activation_4 (Activation)      (None, 8, 8, 64)     0           ['add_1[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 8, 8, 64)     36928       ['activation_4[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 8, 8, 64)    256         ['conv2d_5[0][0]']
#  rmalization)
#
#  activation_5 (Activation)      (None, 8, 8, 64)     0           ['batch_normalization_5[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 8, 8, 64)     36928       ['activation_5[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 8, 8, 64)    256         ['conv2d_6[0][0]']
#  rmalization)
#
#  add_2 (Add)                    (None, 8, 8, 64)     0           ['batch_normalization_6[0][0]',
#                                                                   'activation_4[0][0]']
#
#  activation_6 (Activation)      (None, 8, 8, 64)     0           ['add_2[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 4, 4, 128)    73856       ['activation_6[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 4, 4, 128)   512         ['conv2d_8[0][0]']
#  rmalization)
#
#  activation_7 (Activation)      (None, 4, 4, 128)    0           ['batch_normalization_8[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 4, 4, 128)    147584      ['activation_7[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 4, 4, 128)    8320        ['activation_6[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 4, 4, 128)   512         ['conv2d_9[0][0]']
#  rmalization)
#
#  batch_normalization_7 (BatchNo  (None, 4, 4, 128)   512         ['conv2d_7[0][0]']
#  rmalization)
#
#  add_3 (Add)                    (None, 4, 4, 128)    0           ['batch_normalization_9[0][0]',
#                                                                   'batch_normalization_7[0][0]']
#
#  activation_8 (Activation)      (None, 4, 4, 128)    0           ['add_3[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 4, 4, 128)    147584      ['activation_8[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 4, 4, 128)   512         ['conv2d_10[0][0]']
#  ormalization)
#
#  activation_9 (Activation)      (None, 4, 4, 128)    0           ['batch_normalization_10[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 4, 4, 128)    147584      ['activation_9[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 4, 4, 128)   512         ['conv2d_11[0][0]']
#  ormalization)
#
#  add_4 (Add)                    (None, 4, 4, 128)    0           ['batch_normalization_11[0][0]',
#                                                                   'activation_8[0][0]']
#
#  activation_10 (Activation)     (None, 4, 4, 128)    0           ['add_4[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 4, 4, 128)    147584      ['activation_10[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 4, 4, 128)   512         ['conv2d_12[0][0]']
#  ormalization)
#
#  activation_11 (Activation)     (None, 4, 4, 128)    0           ['batch_normalization_12[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 4, 4, 128)    147584      ['activation_11[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 4, 4, 128)   512         ['conv2d_13[0][0]']
#  ormalization)
#
#  add_5 (Add)                    (None, 4, 4, 128)    0           ['batch_normalization_13[0][0]',
#                                                                   'activation_10[0][0]']
#
#  activation_12 (Activation)     (None, 4, 4, 128)    0           ['add_5[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 4, 4, 128)    147584      ['activation_12[0][0]']
#
#  batch_normalization_14 (BatchN  (None, 4, 4, 128)   512         ['conv2d_14[0][0]']
#  ormalization)
#
#  activation_13 (Activation)     (None, 4, 4, 128)    0           ['batch_normalization_14[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 4, 4, 128)    147584      ['activation_13[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 4, 4, 128)   512         ['conv2d_15[0][0]']
#  ormalization)
#
#  add_6 (Add)                    (None, 4, 4, 128)    0           ['batch_normalization_15[0][0]',
#                                                                   'activation_12[0][0]']
#
#  activation_14 (Activation)     (None, 4, 4, 128)    0           ['add_6[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 2, 2, 256)    295168      ['activation_14[0][0]']
#
#  batch_normalization_17 (BatchN  (None, 2, 2, 256)   1024        ['conv2d_17[0][0]']
#  ormalization)
#
#  activation_15 (Activation)     (None, 2, 2, 256)    0           ['batch_normalization_17[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 2, 2, 256)    590080      ['activation_15[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 2, 2, 256)    33024       ['activation_14[0][0]']
#
#  batch_normalization_18 (BatchN  (None, 2, 2, 256)   1024        ['conv2d_18[0][0]']
#  ormalization)
#
#  batch_normalization_16 (BatchN  (None, 2, 2, 256)   1024        ['conv2d_16[0][0]']
#  ormalization)
#
#  add_7 (Add)                    (None, 2, 2, 256)    0           ['batch_normalization_18[0][0]',
#                                                                   'batch_normalization_16[0][0]']
#
#  activation_16 (Activation)     (None, 2, 2, 256)    0           ['add_7[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 2, 2, 256)    590080      ['activation_16[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 2, 2, 256)   1024        ['conv2d_19[0][0]']
#  ormalization)
#
#  activation_17 (Activation)     (None, 2, 2, 256)    0           ['batch_normalization_19[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 2, 2, 256)    590080      ['activation_17[0][0]']
#
#  batch_normalization_20 (BatchN  (None, 2, 2, 256)   1024        ['conv2d_20[0][0]']
#  ormalization)
#
#  add_8 (Add)                    (None, 2, 2, 256)    0           ['batch_normalization_20[0][0]',
#                                                                   'activation_16[0][0]']
#
#  activation_18 (Activation)     (None, 2, 2, 256)    0           ['add_8[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 2, 2, 256)    590080      ['activation_18[0][0]']
#
#  batch_normalization_21 (BatchN  (None, 2, 2, 256)   1024        ['conv2d_21[0][0]']
#  ormalization)
#
#  activation_19 (Activation)     (None, 2, 2, 256)    0           ['batch_normalization_21[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 2, 2, 256)    590080      ['activation_19[0][0]']
#
#  batch_normalization_22 (BatchN  (None, 2, 2, 256)   1024        ['conv2d_22[0][0]']
#  ormalization)
#
#  add_9 (Add)                    (None, 2, 2, 256)    0           ['batch_normalization_22[0][0]',
#                                                                   'activation_18[0][0]']
#
#  activation_20 (Activation)     (None, 2, 2, 256)    0           ['add_9[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 2, 2, 256)    590080      ['activation_20[0][0]']
#
#  batch_normalization_23 (BatchN  (None, 2, 2, 256)   1024        ['conv2d_23[0][0]']
#  ormalization)
#
#  activation_21 (Activation)     (None, 2, 2, 256)    0           ['batch_normalization_23[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 2, 2, 256)    590080      ['activation_21[0][0]']
#
#  batch_normalization_24 (BatchN  (None, 2, 2, 256)   1024        ['conv2d_24[0][0]']
#  ormalization)
#
#  add_10 (Add)                   (None, 2, 2, 256)    0           ['batch_normalization_24[0][0]',
#                                                                   'activation_20[0][0]']
#
#  activation_22 (Activation)     (None, 2, 2, 256)    0           ['add_10[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 2, 2, 256)    590080      ['activation_22[0][0]']
#
#  batch_normalization_25 (BatchN  (None, 2, 2, 256)   1024        ['conv2d_25[0][0]']
#  ormalization)
#
#  activation_23 (Activation)     (None, 2, 2, 256)    0           ['batch_normalization_25[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 2, 2, 256)    590080      ['activation_23[0][0]']
#
#  batch_normalization_26 (BatchN  (None, 2, 2, 256)   1024        ['conv2d_26[0][0]']
#  ormalization)
#
#  add_11 (Add)                   (None, 2, 2, 256)    0           ['batch_normalization_26[0][0]',
#                                                                   'activation_22[0][0]']
#
#  activation_24 (Activation)     (None, 2, 2, 256)    0           ['add_11[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 2, 2, 256)    590080      ['activation_24[0][0]']
#
#  batch_normalization_27 (BatchN  (None, 2, 2, 256)   1024        ['conv2d_27[0][0]']
#  ormalization)
#
#  activation_25 (Activation)     (None, 2, 2, 256)    0           ['batch_normalization_27[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 2, 2, 256)    590080      ['activation_25[0][0]']
#
#  batch_normalization_28 (BatchN  (None, 2, 2, 256)   1024        ['conv2d_28[0][0]']
#  ormalization)
#
#  add_12 (Add)                   (None, 2, 2, 256)    0           ['batch_normalization_28[0][0]',
#                                                                   'activation_24[0][0]']
#
#  activation_26 (Activation)     (None, 2, 2, 256)    0           ['add_12[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 1, 1, 512)    1180160     ['activation_26[0][0]']
#
#  batch_normalization_30 (BatchN  (None, 1, 1, 512)   2048        ['conv2d_30[0][0]']
#  ormalization)
#
#  activation_27 (Activation)     (None, 1, 1, 512)    0           ['batch_normalization_30[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 1, 1, 512)    2359808     ['activation_27[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 1, 1, 512)    131584      ['activation_26[0][0]']
#
#  batch_normalization_31 (BatchN  (None, 1, 1, 512)   2048        ['conv2d_31[0][0]']
#  ormalization)
#
#  batch_normalization_29 (BatchN  (None, 1, 1, 512)   2048        ['conv2d_29[0][0]']
#  ormalization)
#
#  add_13 (Add)                   (None, 1, 1, 512)    0           ['batch_normalization_31[0][0]',
#                                                                   'batch_normalization_29[0][0]']
#
#  activation_28 (Activation)     (None, 1, 1, 512)    0           ['add_13[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 1, 1, 512)    2359808     ['activation_28[0][0]']
#
#  batch_normalization_32 (BatchN  (None, 1, 1, 512)   2048        ['conv2d_32[0][0]']
#  ormalization)
#
#  activation_29 (Activation)     (None, 1, 1, 512)    0           ['batch_normalization_32[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 1, 1, 512)    2359808     ['activation_29[0][0]']
#
#  batch_normalization_33 (BatchN  (None, 1, 1, 512)   2048        ['conv2d_33[0][0]']
#  ormalization)
#
#  add_14 (Add)                   (None, 1, 1, 512)    0           ['batch_normalization_33[0][0]',
#                                                                   'activation_28[0][0]']
#
#  activation_30 (Activation)     (None, 1, 1, 512)    0           ['add_14[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 1, 1, 512)    2359808     ['activation_30[0][0]']
#
#  batch_normalization_34 (BatchN  (None, 1, 1, 512)   2048        ['conv2d_34[0][0]']
#  ormalization)
#
#  activation_31 (Activation)     (None, 1, 1, 512)    0           ['batch_normalization_34[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 1, 1, 512)    2359808     ['activation_31[0][0]']
#
#  batch_normalization_35 (BatchN  (None, 1, 1, 512)   2048        ['conv2d_35[0][0]']
#  ormalization)
#
#  add_15 (Add)                   (None, 1, 1, 512)    0           ['batch_normalization_35[0][0]',
#                                                                   'activation_30[0][0]']
#
#  activation_32 (Activation)     (None, 1, 1, 512)    0           ['add_15[0][0]']
#
#  global_average_pooling2d (Glob  (None, 512)         0           ['activation_32[0][0]']
#  alAveragePooling2D)
#
#  dense (Dense)                  (None, 10)           5130        ['global_average_pooling2d[0][0]'
#                                                                  ]
#
# ==================================================================================================
# Total params: 21,315,338
# Trainable params: 21,298,314
# Non-trainable params: 17,024
# __________________________________________________________________________________________________
# Model: "ResNet_50"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 32, 32, 3)]  0           []
#
#  conv2d_89 (Conv2D)             (None, 16, 16, 64)   9472        ['input_3[0][0]']
#
#  batch_normalization_89 (BatchN  (None, 16, 16, 64)  256         ['conv2d_89[0][0]']
#  ormalization)
#
#  activation_82 (Activation)     (None, 16, 16, 64)   0           ['batch_normalization_89[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 8, 8, 64)    0           ['activation_82[0][0]']
#
#  conv2d_90 (Conv2D)             (None, 8, 8, 64)     36928       ['max_pooling2d_2[0][0]']
#
#  batch_normalization_90 (BatchN  (None, 8, 8, 64)    256         ['conv2d_90[0][0]']
#  ormalization)
#
#  activation_83 (Activation)     (None, 8, 8, 64)     0           ['batch_normalization_90[0][0]']
#
#  conv2d_91 (Conv2D)             (None, 8, 8, 64)     36928       ['activation_83[0][0]']
#
#  batch_normalization_91 (BatchN  (None, 8, 8, 64)    256         ['conv2d_91[0][0]']
#  ormalization)
#
#  add_32 (Add)                   (None, 8, 8, 64)     0           ['batch_normalization_91[0][0]',
#                                                                   'max_pooling2d_2[0][0]']
#
#  activation_84 (Activation)     (None, 8, 8, 64)     0           ['add_32[0][0]']
#
#  conv2d_92 (Conv2D)             (None, 8, 8, 64)     36928       ['activation_84[0][0]']
#
#  batch_normalization_92 (BatchN  (None, 8, 8, 64)    256         ['conv2d_92[0][0]']
#  ormalization)
#
#  activation_85 (Activation)     (None, 8, 8, 64)     0           ['batch_normalization_92[0][0]']
#
#  conv2d_93 (Conv2D)             (None, 8, 8, 64)     36928       ['activation_85[0][0]']
#
#  batch_normalization_93 (BatchN  (None, 8, 8, 64)    256         ['conv2d_93[0][0]']
#  ormalization)
#
#  add_33 (Add)                   (None, 8, 8, 64)     0           ['batch_normalization_93[0][0]',
#                                                                   'activation_84[0][0]']
#
#  activation_86 (Activation)     (None, 8, 8, 64)     0           ['add_33[0][0]']
#
#  conv2d_94 (Conv2D)             (None, 8, 8, 64)     36928       ['activation_86[0][0]']
#
#  batch_normalization_94 (BatchN  (None, 8, 8, 64)    256         ['conv2d_94[0][0]']
#  ormalization)
#
#  activation_87 (Activation)     (None, 8, 8, 64)     0           ['batch_normalization_94[0][0]']
#
#  conv2d_95 (Conv2D)             (None, 8, 8, 64)     36928       ['activation_87[0][0]']
#
#  batch_normalization_95 (BatchN  (None, 8, 8, 64)    256         ['conv2d_95[0][0]']
#  ormalization)
#
#  add_34 (Add)                   (None, 8, 8, 64)     0           ['batch_normalization_95[0][0]',
#                                                                   'activation_86[0][0]']
#
#  activation_88 (Activation)     (None, 8, 8, 64)     0           ['add_34[0][0]']
#
#  conv2d_97 (Conv2D)             (None, 4, 4, 128)    73856       ['activation_88[0][0]']
#
#  batch_normalization_97 (BatchN  (None, 4, 4, 128)   512         ['conv2d_97[0][0]']
#  ormalization)
#
#  activation_89 (Activation)     (None, 4, 4, 128)    0           ['batch_normalization_97[0][0]']
#
#  conv2d_98 (Conv2D)             (None, 4, 4, 128)    147584      ['activation_89[0][0]']
#
#  conv2d_96 (Conv2D)             (None, 4, 4, 128)    8320        ['activation_88[0][0]']
#
#  batch_normalization_98 (BatchN  (None, 4, 4, 128)   512         ['conv2d_98[0][0]']
#  ormalization)
#
#  batch_normalization_96 (BatchN  (None, 4, 4, 128)   512         ['conv2d_96[0][0]']
#  ormalization)
#
#  add_35 (Add)                   (None, 4, 4, 128)    0           ['batch_normalization_98[0][0]',
#                                                                   'batch_normalization_96[0][0]']
#
#  activation_90 (Activation)     (None, 4, 4, 128)    0           ['add_35[0][0]']
#
#  conv2d_99 (Conv2D)             (None, 4, 4, 128)    147584      ['activation_90[0][0]']
#
#  batch_normalization_99 (BatchN  (None, 4, 4, 128)   512         ['conv2d_99[0][0]']
#  ormalization)
#
#  activation_91 (Activation)     (None, 4, 4, 128)    0           ['batch_normalization_99[0][0]']
#
#  conv2d_100 (Conv2D)            (None, 4, 4, 128)    147584      ['activation_91[0][0]']
#
#  batch_normalization_100 (Batch  (None, 4, 4, 128)   512         ['conv2d_100[0][0]']
#  Normalization)
#
#  add_36 (Add)                   (None, 4, 4, 128)    0           ['batch_normalization_100[0][0]',
#                                                                   'activation_90[0][0]']
#
#  activation_92 (Activation)     (None, 4, 4, 128)    0           ['add_36[0][0]']
#
#  conv2d_101 (Conv2D)            (None, 4, 4, 128)    147584      ['activation_92[0][0]']
#
#  batch_normalization_101 (Batch  (None, 4, 4, 128)   512         ['conv2d_101[0][0]']
#  Normalization)
#
#  activation_93 (Activation)     (None, 4, 4, 128)    0           ['batch_normalization_101[0][0]']
#
#  conv2d_102 (Conv2D)            (None, 4, 4, 128)    147584      ['activation_93[0][0]']
#
#  batch_normalization_102 (Batch  (None, 4, 4, 128)   512         ['conv2d_102[0][0]']
#  Normalization)
#
#  add_37 (Add)                   (None, 4, 4, 128)    0           ['batch_normalization_102[0][0]',
#                                                                   'activation_92[0][0]']
#
#  activation_94 (Activation)     (None, 4, 4, 128)    0           ['add_37[0][0]']
#
#  conv2d_103 (Conv2D)            (None, 4, 4, 128)    147584      ['activation_94[0][0]']
#
#  batch_normalization_103 (Batch  (None, 4, 4, 128)   512         ['conv2d_103[0][0]']
#  Normalization)
#
#  activation_95 (Activation)     (None, 4, 4, 128)    0           ['batch_normalization_103[0][0]']
#
#  conv2d_104 (Conv2D)            (None, 4, 4, 128)    147584      ['activation_95[0][0]']
#
#  batch_normalization_104 (Batch  (None, 4, 4, 128)   512         ['conv2d_104[0][0]']
#  Normalization)
#
#  add_38 (Add)                   (None, 4, 4, 128)    0           ['batch_normalization_104[0][0]',
#                                                                   'activation_94[0][0]']
#
#  activation_96 (Activation)     (None, 4, 4, 128)    0           ['add_38[0][0]']
#
#  conv2d_106 (Conv2D)            (None, 2, 2, 256)    295168      ['activation_96[0][0]']
#
#  batch_normalization_106 (Batch  (None, 2, 2, 256)   1024        ['conv2d_106[0][0]']
#  Normalization)
#
#  activation_97 (Activation)     (None, 2, 2, 256)    0           ['batch_normalization_106[0][0]']
#
#  conv2d_107 (Conv2D)            (None, 2, 2, 256)    590080      ['activation_97[0][0]']
#
#  conv2d_105 (Conv2D)            (None, 2, 2, 256)    33024       ['activation_96[0][0]']
#
#  batch_normalization_107 (Batch  (None, 2, 2, 256)   1024        ['conv2d_107[0][0]']
#  Normalization)
#
#  batch_normalization_105 (Batch  (None, 2, 2, 256)   1024        ['conv2d_105[0][0]']
#  Normalization)
#
#  add_39 (Add)                   (None, 2, 2, 256)    0           ['batch_normalization_107[0][0]',
#                                                                   'batch_normalization_105[0][0]']
#
#  activation_98 (Activation)     (None, 2, 2, 256)    0           ['add_39[0][0]']
#
#  conv2d_108 (Conv2D)            (None, 2, 2, 256)    590080      ['activation_98[0][0]']
#
#  batch_normalization_108 (Batch  (None, 2, 2, 256)   1024        ['conv2d_108[0][0]']
#  Normalization)
#
#  activation_99 (Activation)     (None, 2, 2, 256)    0           ['batch_normalization_108[0][0]']
#
#  conv2d_109 (Conv2D)            (None, 2, 2, 256)    590080      ['activation_99[0][0]']
#
#  batch_normalization_109 (Batch  (None, 2, 2, 256)   1024        ['conv2d_109[0][0]']
#  Normalization)
#
#  add_40 (Add)                   (None, 2, 2, 256)    0           ['batch_normalization_109[0][0]',
#                                                                   'activation_98[0][0]']
#
#  activation_100 (Activation)    (None, 2, 2, 256)    0           ['add_40[0][0]']
#
#  conv2d_110 (Conv2D)            (None, 2, 2, 256)    590080      ['activation_100[0][0]']
#
#  batch_normalization_110 (Batch  (None, 2, 2, 256)   1024        ['conv2d_110[0][0]']
#  Normalization)
#
#  activation_101 (Activation)    (None, 2, 2, 256)    0           ['batch_normalization_110[0][0]']
#
#  conv2d_111 (Conv2D)            (None, 2, 2, 256)    590080      ['activation_101[0][0]']
#
#  batch_normalization_111 (Batch  (None, 2, 2, 256)   1024        ['conv2d_111[0][0]']
#  Normalization)
#
#  add_41 (Add)                   (None, 2, 2, 256)    0           ['batch_normalization_111[0][0]',
#                                                                   'activation_100[0][0]']
#
#  activation_102 (Activation)    (None, 2, 2, 256)    0           ['add_41[0][0]']
#
#  conv2d_112 (Conv2D)            (None, 2, 2, 256)    590080      ['activation_102[0][0]']
#
#  batch_normalization_112 (Batch  (None, 2, 2, 256)   1024        ['conv2d_112[0][0]']
#  Normalization)
#
#  activation_103 (Activation)    (None, 2, 2, 256)    0           ['batch_normalization_112[0][0]']
#
#  conv2d_113 (Conv2D)            (None, 2, 2, 256)    590080      ['activation_103[0][0]']
#
#  batch_normalization_113 (Batch  (None, 2, 2, 256)   1024        ['conv2d_113[0][0]']
#  Normalization)
#
#  add_42 (Add)                   (None, 2, 2, 256)    0           ['batch_normalization_113[0][0]',
#                                                                   'activation_102[0][0]']
#
#  activation_104 (Activation)    (None, 2, 2, 256)    0           ['add_42[0][0]']
#
#  conv2d_114 (Conv2D)            (None, 2, 2, 256)    590080      ['activation_104[0][0]']
#
#  batch_normalization_114 (Batch  (None, 2, 2, 256)   1024        ['conv2d_114[0][0]']
#  Normalization)
#
#  activation_105 (Activation)    (None, 2, 2, 256)    0           ['batch_normalization_114[0][0]']
#
#  conv2d_115 (Conv2D)            (None, 2, 2, 256)    590080      ['activation_105[0][0]']
#
#  batch_normalization_115 (Batch  (None, 2, 2, 256)   1024        ['conv2d_115[0][0]']
#  Normalization)
#
#  add_43 (Add)                   (None, 2, 2, 256)    0           ['batch_normalization_115[0][0]',
#                                                                   'activation_104[0][0]']
#
#  activation_106 (Activation)    (None, 2, 2, 256)    0           ['add_43[0][0]']
#
#  conv2d_116 (Conv2D)            (None, 2, 2, 256)    590080      ['activation_106[0][0]']
#
#  batch_normalization_116 (Batch  (None, 2, 2, 256)   1024        ['conv2d_116[0][0]']
#  Normalization)
#
#  activation_107 (Activation)    (None, 2, 2, 256)    0           ['batch_normalization_116[0][0]']
#
#  conv2d_117 (Conv2D)            (None, 2, 2, 256)    590080      ['activation_107[0][0]']
#
#  batch_normalization_117 (Batch  (None, 2, 2, 256)   1024        ['conv2d_117[0][0]']
#  Normalization)
#
#  add_44 (Add)                   (None, 2, 2, 256)    0           ['batch_normalization_117[0][0]',
#                                                                   'activation_106[0][0]']
#
#  activation_108 (Activation)    (None, 2, 2, 256)    0           ['add_44[0][0]']
#
#  conv2d_119 (Conv2D)            (None, 1, 1, 512)    1180160     ['activation_108[0][0]']
#
#  batch_normalization_119 (Batch  (None, 1, 1, 512)   2048        ['conv2d_119[0][0]']
#  Normalization)
#
#  activation_109 (Activation)    (None, 1, 1, 512)    0           ['batch_normalization_119[0][0]']
#
#  conv2d_120 (Conv2D)            (None, 1, 1, 512)    2359808     ['activation_109[0][0]']
#
#  conv2d_118 (Conv2D)            (None, 1, 1, 512)    131584      ['activation_108[0][0]']
#
#  batch_normalization_120 (Batch  (None, 1, 1, 512)   2048        ['conv2d_120[0][0]']
#  Normalization)
#
#  batch_normalization_118 (Batch  (None, 1, 1, 512)   2048        ['conv2d_118[0][0]']
#  Normalization)
#
#  add_45 (Add)                   (None, 1, 1, 512)    0           ['batch_normalization_120[0][0]',
#                                                                   'batch_normalization_118[0][0]']
#
#  activation_110 (Activation)    (None, 1, 1, 512)    0           ['add_45[0][0]']
#
#  conv2d_121 (Conv2D)            (None, 1, 1, 512)    2359808     ['activation_110[0][0]']
#
#  batch_normalization_121 (Batch  (None, 1, 1, 512)   2048        ['conv2d_121[0][0]']
#  Normalization)
#
#  activation_111 (Activation)    (None, 1, 1, 512)    0           ['batch_normalization_121[0][0]']
#
#  conv2d_122 (Conv2D)            (None, 1, 1, 512)    2359808     ['activation_111[0][0]']
#
#  batch_normalization_122 (Batch  (None, 1, 1, 512)   2048        ['conv2d_122[0][0]']
#  Normalization)
#
#  add_46 (Add)                   (None, 1, 1, 512)    0           ['batch_normalization_122[0][0]',
#                                                                   'activation_110[0][0]']
#
#  activation_112 (Activation)    (None, 1, 1, 512)    0           ['add_46[0][0]']
#
#  conv2d_123 (Conv2D)            (None, 1, 1, 512)    2359808     ['activation_112[0][0]']
#
#  batch_normalization_123 (Batch  (None, 1, 1, 512)   2048        ['conv2d_123[0][0]']
#  Normalization)
#
#  activation_113 (Activation)    (None, 1, 1, 512)    0           ['batch_normalization_123[0][0]']
#
#  conv2d_124 (Conv2D)            (None, 1, 1, 512)    2359808     ['activation_113[0][0]']
#
#  batch_normalization_124 (Batch  (None, 1, 1, 512)   2048        ['conv2d_124[0][0]']
#  Normalization)
#
#  add_47 (Add)                   (None, 1, 1, 512)    0           ['batch_normalization_124[0][0]',
#                                                                   'activation_112[0][0]']
#
#  activation_114 (Activation)    (None, 1, 1, 512)    0           ['add_47[0][0]']
#
#  global_average_pooling2d_2 (Gl  (None, 512)         0           ['activation_114[0][0]']
#  obalAveragePooling2D)
#
#  dense_2 (Dense)                (None, 10)           5130        ['global_average_pooling2d_2[0][0
#                                                                  ]']
#
# ==================================================================================================
# Total params: 21,315,338
# Trainable params: 21,298,314
# Non-trainable params: 17,024
# __________________________________________________________________________________________________

# %% [markdown]
# **ResNet-50**

# %%
resnet_50 = build_resnet(input_shape=(32, 32,3), is_50=True)
resnet_50.summary()
# Out:
# Model: "ResNet_50"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 32, 32, 3)]  0           []
#
#  conv2d_36 (Conv2D)             (None, 16, 16, 64)   9472        ['input_2[0][0]']
#
#  batch_normalization_36 (BatchN  (None, 16, 16, 64)  256         ['conv2d_36[0][0]']
#  ormalization)
#
#  activation_33 (Activation)     (None, 16, 16, 64)   0           ['batch_normalization_36[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 8, 8, 64)    0           ['activation_33[0][0]']
#
#  conv2d_38 (Conv2D)             (None, 4, 4, 64)     4160        ['max_pooling2d_1[0][0]']
#
#  batch_normalization_38 (BatchN  (None, 4, 4, 64)    256         ['conv2d_38[0][0]']
#  ormalization)
#
#  activation_34 (Activation)     (None, 4, 4, 64)     0           ['batch_normalization_38[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 4, 4, 64)     36928       ['activation_34[0][0]']
#
#  batch_normalization_39 (BatchN  (None, 4, 4, 64)    256         ['conv2d_39[0][0]']
#  ormalization)
#
#  activation_35 (Activation)     (None, 4, 4, 64)     0           ['batch_normalization_39[0][0]']
#
#  conv2d_40 (Conv2D)             (None, 4, 4, 256)    16640       ['activation_35[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 4, 4, 256)    16640       ['max_pooling2d_1[0][0]']
#
#  batch_normalization_40 (BatchN  (None, 4, 4, 256)   1024        ['conv2d_40[0][0]']
#  ormalization)
#
#  batch_normalization_37 (BatchN  (None, 4, 4, 256)   1024        ['conv2d_37[0][0]']
#  ormalization)
#
#  add_16 (Add)                   (None, 4, 4, 256)    0           ['batch_normalization_40[0][0]',
#                                                                   'batch_normalization_37[0][0]']
#
#  activation_36 (Activation)     (None, 4, 4, 256)    0           ['add_16[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 4, 4, 64)     16448       ['activation_36[0][0]']
#
#  batch_normalization_41 (BatchN  (None, 4, 4, 64)    256         ['conv2d_41[0][0]']
#  ormalization)
#
#  activation_37 (Activation)     (None, 4, 4, 64)     0           ['batch_normalization_41[0][0]']
#
#  conv2d_42 (Conv2D)             (None, 4, 4, 64)     36928       ['activation_37[0][0]']
#
#  batch_normalization_42 (BatchN  (None, 4, 4, 64)    256         ['conv2d_42[0][0]']
#  ormalization)
#
#  activation_38 (Activation)     (None, 4, 4, 64)     0           ['batch_normalization_42[0][0]']
#
#  conv2d_43 (Conv2D)             (None, 4, 4, 256)    16640       ['activation_38[0][0]']
#
#  batch_normalization_43 (BatchN  (None, 4, 4, 256)   1024        ['conv2d_43[0][0]']
#  ormalization)
#
#  add_17 (Add)                   (None, 4, 4, 256)    0           ['batch_normalization_43[0][0]',
#                                                                   'activation_36[0][0]']
#
#  activation_39 (Activation)     (None, 4, 4, 256)    0           ['add_17[0][0]']
#
#  conv2d_44 (Conv2D)             (None, 4, 4, 64)     16448       ['activation_39[0][0]']
#
#  batch_normalization_44 (BatchN  (None, 4, 4, 64)    256         ['conv2d_44[0][0]']
#  ormalization)
#
#  activation_40 (Activation)     (None, 4, 4, 64)     0           ['batch_normalization_44[0][0]']
#
#  conv2d_45 (Conv2D)             (None, 4, 4, 64)     36928       ['activation_40[0][0]']
#
#  batch_normalization_45 (BatchN  (None, 4, 4, 64)    256         ['conv2d_45[0][0]']
#  ormalization)
#
#  activation_41 (Activation)     (None, 4, 4, 64)     0           ['batch_normalization_45[0][0]']
#
#  conv2d_46 (Conv2D)             (None, 4, 4, 256)    16640       ['activation_41[0][0]']
#
#  batch_normalization_46 (BatchN  (None, 4, 4, 256)   1024        ['conv2d_46[0][0]']
#  ormalization)
#
#  add_18 (Add)                   (None, 4, 4, 256)    0           ['batch_normalization_46[0][0]',
#                                                                   'activation_39[0][0]']
#
#  activation_42 (Activation)     (None, 4, 4, 256)    0           ['add_18[0][0]']
#
#  conv2d_48 (Conv2D)             (None, 2, 2, 128)    32896       ['activation_42[0][0]']
#
#  batch_normalization_48 (BatchN  (None, 2, 2, 128)   512         ['conv2d_48[0][0]']
#  ormalization)
#
#  activation_43 (Activation)     (None, 2, 2, 128)    0           ['batch_normalization_48[0][0]']
#
#  conv2d_49 (Conv2D)             (None, 2, 2, 128)    147584      ['activation_43[0][0]']
#
#  batch_normalization_49 (BatchN  (None, 2, 2, 128)   512         ['conv2d_49[0][0]']
#  ormalization)
#
#  activation_44 (Activation)     (None, 2, 2, 128)    0           ['batch_normalization_49[0][0]']
#
#  conv2d_50 (Conv2D)             (None, 2, 2, 512)    66048       ['activation_44[0][0]']
#
#  conv2d_47 (Conv2D)             (None, 2, 2, 512)    131584      ['activation_42[0][0]']
#
#  batch_normalization_50 (BatchN  (None, 2, 2, 512)   2048        ['conv2d_50[0][0]']
#  ormalization)
#
#  batch_normalization_47 (BatchN  (None, 2, 2, 512)   2048        ['conv2d_47[0][0]']
#  ormalization)
#
#  add_19 (Add)                   (None, 2, 2, 512)    0           ['batch_normalization_50[0][0]',
#                                                                   'batch_normalization_47[0][0]']
#
#  activation_45 (Activation)     (None, 2, 2, 512)    0           ['add_19[0][0]']
#
#  conv2d_51 (Conv2D)             (None, 2, 2, 128)    65664       ['activation_45[0][0]']
#
#  batch_normalization_51 (BatchN  (None, 2, 2, 128)   512         ['conv2d_51[0][0]']
#  ormalization)
#
#  activation_46 (Activation)     (None, 2, 2, 128)    0           ['batch_normalization_51[0][0]']
#
#  conv2d_52 (Conv2D)             (None, 2, 2, 128)    147584      ['activation_46[0][0]']
#
#  batch_normalization_52 (BatchN  (None, 2, 2, 128)   512         ['conv2d_52[0][0]']
#  ormalization)
#
#  activation_47 (Activation)     (None, 2, 2, 128)    0           ['batch_normalization_52[0][0]']
#
#  conv2d_53 (Conv2D)             (None, 2, 2, 512)    66048       ['activation_47[0][0]']
#
#  batch_normalization_53 (BatchN  (None, 2, 2, 512)   2048        ['conv2d_53[0][0]']
#  ormalization)
#
#  add_20 (Add)                   (None, 2, 2, 512)    0           ['batch_normalization_53[0][0]',
#                                                                   'activation_45[0][0]']
#
#  activation_48 (Activation)     (None, 2, 2, 512)    0           ['add_20[0][0]']
#
#  conv2d_54 (Conv2D)             (None, 2, 2, 128)    65664       ['activation_48[0][0]']
#
#  batch_normalization_54 (BatchN  (None, 2, 2, 128)   512         ['conv2d_54[0][0]']
#  ormalization)
#
#  activation_49 (Activation)     (None, 2, 2, 128)    0           ['batch_normalization_54[0][0]']
#
#  conv2d_55 (Conv2D)             (None, 2, 2, 128)    147584      ['activation_49[0][0]']
#
#  batch_normalization_55 (BatchN  (None, 2, 2, 128)   512         ['conv2d_55[0][0]']
#  ormalization)
#
#  activation_50 (Activation)     (None, 2, 2, 128)    0           ['batch_normalization_55[0][0]']
#
#  conv2d_56 (Conv2D)             (None, 2, 2, 512)    66048       ['activation_50[0][0]']
#
#  batch_normalization_56 (BatchN  (None, 2, 2, 512)   2048        ['conv2d_56[0][0]']
#  ormalization)
#
#  add_21 (Add)                   (None, 2, 2, 512)    0           ['batch_normalization_56[0][0]',
#                                                                   'activation_48[0][0]']
#
#  activation_51 (Activation)     (None, 2, 2, 512)    0           ['add_21[0][0]']
#
#  conv2d_57 (Conv2D)             (None, 2, 2, 128)    65664       ['activation_51[0][0]']
#
#  batch_normalization_57 (BatchN  (None, 2, 2, 128)   512         ['conv2d_57[0][0]']
#  ormalization)
#
#  activation_52 (Activation)     (None, 2, 2, 128)    0           ['batch_normalization_57[0][0]']
#
#  conv2d_58 (Conv2D)             (None, 2, 2, 128)    147584      ['activation_52[0][0]']
#
#  batch_normalization_58 (BatchN  (None, 2, 2, 128)   512         ['conv2d_58[0][0]']
#  ormalization)
#
#  activation_53 (Activation)     (None, 2, 2, 128)    0           ['batch_normalization_58[0][0]']
#
#  conv2d_59 (Conv2D)             (None, 2, 2, 512)    66048       ['activation_53[0][0]']
#
#  batch_normalization_59 (BatchN  (None, 2, 2, 512)   2048        ['conv2d_59[0][0]']
#  ormalization)
#
#  add_22 (Add)                   (None, 2, 2, 512)    0           ['batch_normalization_59[0][0]',
#                                                                   'activation_51[0][0]']
#
#  activation_54 (Activation)     (None, 2, 2, 512)    0           ['add_22[0][0]']
#
#  conv2d_61 (Conv2D)             (None, 1, 1, 256)    131328      ['activation_54[0][0]']
#
#  batch_normalization_61 (BatchN  (None, 1, 1, 256)   1024        ['conv2d_61[0][0]']
#  ormalization)
#
#  activation_55 (Activation)     (None, 1, 1, 256)    0           ['batch_normalization_61[0][0]']
#
#  conv2d_62 (Conv2D)             (None, 1, 1, 256)    590080      ['activation_55[0][0]']
#
#  batch_normalization_62 (BatchN  (None, 1, 1, 256)   1024        ['conv2d_62[0][0]']
#  ormalization)
#
#  activation_56 (Activation)     (None, 1, 1, 256)    0           ['batch_normalization_62[0][0]']
#
#  conv2d_63 (Conv2D)             (None, 1, 1, 1024)   263168      ['activation_56[0][0]']
#
#  conv2d_60 (Conv2D)             (None, 1, 1, 1024)   525312      ['activation_54[0][0]']
#
#  batch_normalization_63 (BatchN  (None, 1, 1, 1024)  4096        ['conv2d_63[0][0]']
#  ormalization)
#
#  batch_normalization_60 (BatchN  (None, 1, 1, 1024)  4096        ['conv2d_60[0][0]']
#  ormalization)
#
#  add_23 (Add)                   (None, 1, 1, 1024)   0           ['batch_normalization_63[0][0]',
#                                                                   'batch_normalization_60[0][0]']
#
#  activation_57 (Activation)     (None, 1, 1, 1024)   0           ['add_23[0][0]']
#
#  conv2d_64 (Conv2D)             (None, 1, 1, 256)    262400      ['activation_57[0][0]']
#
#  batch_normalization_64 (BatchN  (None, 1, 1, 256)   1024        ['conv2d_64[0][0]']
#  ormalization)
#
#  activation_58 (Activation)     (None, 1, 1, 256)    0           ['batch_normalization_64[0][0]']
#
#  conv2d_65 (Conv2D)             (None, 1, 1, 256)    590080      ['activation_58[0][0]']
#
#  batch_normalization_65 (BatchN  (None, 1, 1, 256)   1024        ['conv2d_65[0][0]']
#  ormalization)
#
#  activation_59 (Activation)     (None, 1, 1, 256)    0           ['batch_normalization_65[0][0]']
#
#  conv2d_66 (Conv2D)             (None, 1, 1, 1024)   263168      ['activation_59[0][0]']
#
#  batch_normalization_66 (BatchN  (None, 1, 1, 1024)  4096        ['conv2d_66[0][0]']
#  ormalization)
#
#  add_24 (Add)                   (None, 1, 1, 1024)   0           ['batch_normalization_66[0][0]',
#                                                                   'activation_57[0][0]']
#
#  activation_60 (Activation)     (None, 1, 1, 1024)   0           ['add_24[0][0]']
#
#  conv2d_67 (Conv2D)             (None, 1, 1, 256)    262400      ['activation_60[0][0]']
#
#  batch_normalization_67 (BatchN  (None, 1, 1, 256)   1024        ['conv2d_67[0][0]']
#  ormalization)
#
#  activation_61 (Activation)     (None, 1, 1, 256)    0           ['batch_normalization_67[0][0]']
#
#  conv2d_68 (Conv2D)             (None, 1, 1, 256)    590080      ['activation_61[0][0]']
#
#  batch_normalization_68 (BatchN  (None, 1, 1, 256)   1024        ['conv2d_68[0][0]']
#  ormalization)
#
#  activation_62 (Activation)     (None, 1, 1, 256)    0           ['batch_normalization_68[0][0]']
#
#  conv2d_69 (Conv2D)             (None, 1, 1, 1024)   263168      ['activation_62[0][0]']
#
#  batch_normalization_69 (BatchN  (None, 1, 1, 1024)  4096        ['conv2d_69[0][0]']
#  ormalization)
#
#  add_25 (Add)                   (None, 1, 1, 1024)   0           ['batch_normalization_69[0][0]',
#                                                                   'activation_60[0][0]']
#
#  activation_63 (Activation)     (None, 1, 1, 1024)   0           ['add_25[0][0]']
#
#  conv2d_70 (Conv2D)             (None, 1, 1, 256)    262400      ['activation_63[0][0]']
#
#  batch_normalization_70 (BatchN  (None, 1, 1, 256)   1024        ['conv2d_70[0][0]']
#  ormalization)
#
#  activation_64 (Activation)     (None, 1, 1, 256)    0           ['batch_normalization_70[0][0]']
#
#  conv2d_71 (Conv2D)             (None, 1, 1, 256)    590080      ['activation_64[0][0]']
#
#  batch_normalization_71 (BatchN  (None, 1, 1, 256)   1024        ['conv2d_71[0][0]']
#  ormalization)
#
#  activation_65 (Activation)     (None, 1, 1, 256)    0           ['batch_normalization_71[0][0]']
#
#  conv2d_72 (Conv2D)             (None, 1, 1, 1024)   263168      ['activation_65[0][0]']
#
#  batch_normalization_72 (BatchN  (None, 1, 1, 1024)  4096        ['conv2d_72[0][0]']
#  ormalization)
#
#  add_26 (Add)                   (None, 1, 1, 1024)   0           ['batch_normalization_72[0][0]',
#                                                                   'activation_63[0][0]']
#
#  activation_66 (Activation)     (None, 1, 1, 1024)   0           ['add_26[0][0]']
#
#  conv2d_73 (Conv2D)             (None, 1, 1, 256)    262400      ['activation_66[0][0]']
#
#  batch_normalization_73 (BatchN  (None, 1, 1, 256)   1024        ['conv2d_73[0][0]']
#  ormalization)
#
#  activation_67 (Activation)     (None, 1, 1, 256)    0           ['batch_normalization_73[0][0]']
#
#  conv2d_74 (Conv2D)             (None, 1, 1, 256)    590080      ['activation_67[0][0]']
#
#  batch_normalization_74 (BatchN  (None, 1, 1, 256)   1024        ['conv2d_74[0][0]']
#  ormalization)
#
#  activation_68 (Activation)     (None, 1, 1, 256)    0           ['batch_normalization_74[0][0]']
#
#  conv2d_75 (Conv2D)             (None, 1, 1, 1024)   263168      ['activation_68[0][0]']
#
#  batch_normalization_75 (BatchN  (None, 1, 1, 1024)  4096        ['conv2d_75[0][0]']
#  ormalization)
#
#  add_27 (Add)                   (None, 1, 1, 1024)   0           ['batch_normalization_75[0][0]',
#                                                                   'activation_66[0][0]']
#
#  activation_69 (Activation)     (None, 1, 1, 1024)   0           ['add_27[0][0]']
#
#  conv2d_76 (Conv2D)             (None, 1, 1, 256)    262400      ['activation_69[0][0]']
#
#  batch_normalization_76 (BatchN  (None, 1, 1, 256)   1024        ['conv2d_76[0][0]']
#  ormalization)
#
#  activation_70 (Activation)     (None, 1, 1, 256)    0           ['batch_normalization_76[0][0]']
#
#  conv2d_77 (Conv2D)             (None, 1, 1, 256)    590080      ['activation_70[0][0]']
#
#  batch_normalization_77 (BatchN  (None, 1, 1, 256)   1024        ['conv2d_77[0][0]']
#  ormalization)
#
#  activation_71 (Activation)     (None, 1, 1, 256)    0           ['batch_normalization_77[0][0]']
#
#  conv2d_78 (Conv2D)             (None, 1, 1, 1024)   263168      ['activation_71[0][0]']
#
#  batch_normalization_78 (BatchN  (None, 1, 1, 1024)  4096        ['conv2d_78[0][0]']
#  ormalization)
#
#  add_28 (Add)                   (None, 1, 1, 1024)   0           ['batch_normalization_78[0][0]',
#                                                                   'activation_69[0][0]']
#
#  activation_72 (Activation)     (None, 1, 1, 1024)   0           ['add_28[0][0]']
#
#  conv2d_80 (Conv2D)             (None, 1, 1, 512)    524800      ['activation_72[0][0]']
#
#  batch_normalization_80 (BatchN  (None, 1, 1, 512)   2048        ['conv2d_80[0][0]']
#  ormalization)
#
#  activation_73 (Activation)     (None, 1, 1, 512)    0           ['batch_normalization_80[0][0]']
#
#  conv2d_81 (Conv2D)             (None, 1, 1, 512)    2359808     ['activation_73[0][0]']
#
#  batch_normalization_81 (BatchN  (None, 1, 1, 512)   2048        ['conv2d_81[0][0]']
#  ormalization)
#
#  activation_74 (Activation)     (None, 1, 1, 512)    0           ['batch_normalization_81[0][0]']
#
#  conv2d_82 (Conv2D)             (None, 1, 1, 2048)   1050624     ['activation_74[0][0]']
#
#  conv2d_79 (Conv2D)             (None, 1, 1, 2048)   2099200     ['activation_72[0][0]']
#
#  batch_normalization_82 (BatchN  (None, 1, 1, 2048)  8192        ['conv2d_82[0][0]']
#  ormalization)
#
#  batch_normalization_79 (BatchN  (None, 1, 1, 2048)  8192        ['conv2d_79[0][0]']
#  ormalization)
#
#  add_29 (Add)                   (None, 1, 1, 2048)   0           ['batch_normalization_82[0][0]',
#                                                                   'batch_normalization_79[0][0]']
#
#  activation_75 (Activation)     (None, 1, 1, 2048)   0           ['add_29[0][0]']
#
#  conv2d_83 (Conv2D)             (None, 1, 1, 512)    1049088     ['activation_75[0][0]']
#
#  batch_normalization_83 (BatchN  (None, 1, 1, 512)   2048        ['conv2d_83[0][0]']
#  ormalization)
#
#  activation_76 (Activation)     (None, 1, 1, 512)    0           ['batch_normalization_83[0][0]']
#
#  conv2d_84 (Conv2D)             (None, 1, 1, 512)    2359808     ['activation_76[0][0]']
#
#  batch_normalization_84 (BatchN  (None, 1, 1, 512)   2048        ['conv2d_84[0][0]']
#  ormalization)
#
#  activation_77 (Activation)     (None, 1, 1, 512)    0           ['batch_normalization_84[0][0]']
#
#  conv2d_85 (Conv2D)             (None, 1, 1, 2048)   1050624     ['activation_77[0][0]']
#
#  batch_normalization_85 (BatchN  (None, 1, 1, 2048)  8192        ['conv2d_85[0][0]']
#  ormalization)
#
#  add_30 (Add)                   (None, 1, 1, 2048)   0           ['batch_normalization_85[0][0]',
#                                                                   'activation_75[0][0]']
#
#  activation_78 (Activation)     (None, 1, 1, 2048)   0           ['add_30[0][0]']
#
#  conv2d_86 (Conv2D)             (None, 1, 1, 512)    1049088     ['activation_78[0][0]']
#
#  batch_normalization_86 (BatchN  (None, 1, 1, 512)   2048        ['conv2d_86[0][0]']
#  ormalization)
#
#  activation_79 (Activation)     (None, 1, 1, 512)    0           ['batch_normalization_86[0][0]']
#
#  conv2d_87 (Conv2D)             (None, 1, 1, 512)    2359808     ['activation_79[0][0]']
#
#  batch_normalization_87 (BatchN  (None, 1, 1, 512)   2048        ['conv2d_87[0][0]']
#  ormalization)
#
#  activation_80 (Activation)     (None, 1, 1, 512)    0           ['batch_normalization_87[0][0]']
#
#  conv2d_88 (Conv2D)             (None, 1, 1, 2048)   1050624     ['activation_80[0][0]']
#
#  batch_normalization_88 (BatchN  (None, 1, 1, 2048)  8192        ['conv2d_88[0][0]']
#  ormalization)
#
#  add_31 (Add)                   (None, 1, 1, 2048)   0           ['batch_normalization_88[0][0]',
#                                                                   'activation_78[0][0]']
#
#  activation_81 (Activation)     (None, 1, 1, 2048)   0           ['add_31[0][0]']
#
#  global_average_pooling2d_1 (Gl  (None, 2048)        0           ['activation_81[0][0]']
#  obalAveragePooling2D)
#
#  dense_1 (Dense)                (None, 10)           20490       ['global_average_pooling2d_1[0][0
#                                                                  ]']
#
# ==================================================================================================
# Total params: 23,608,202
# Trainable params: 23,555,082
# Non-trainable params: 53,120
# __________________________________________________________________________________________________
# Model: "ResNet_50"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_4 (InputLayer)           [(None, 32, 32, 3)]  0           []
#
#  conv2d_125 (Conv2D)            (None, 16, 16, 64)   9472        ['input_4[0][0]']
#
#  batch_normalization_125 (Batch  (None, 16, 16, 64)  256         ['conv2d_125[0][0]']
#  Normalization)
#
#  activation_115 (Activation)    (None, 16, 16, 64)   0           ['batch_normalization_125[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 8, 8, 64)    0           ['activation_115[0][0]']
#
#  conv2d_127 (Conv2D)            (None, 4, 4, 64)     4160        ['max_pooling2d_3[0][0]']
#
#  batch_normalization_127 (Batch  (None, 4, 4, 64)    256         ['conv2d_127[0][0]']
#  Normalization)
#
#  activation_116 (Activation)    (None, 4, 4, 64)     0           ['batch_normalization_127[0][0]']
#
#  conv2d_128 (Conv2D)            (None, 4, 4, 64)     36928       ['activation_116[0][0]']
#
#  batch_normalization_128 (Batch  (None, 4, 4, 64)    256         ['conv2d_128[0][0]']
#  Normalization)
#
#  activation_117 (Activation)    (None, 4, 4, 64)     0           ['batch_normalization_128[0][0]']
#
#  conv2d_129 (Conv2D)            (None, 4, 4, 256)    16640       ['activation_117[0][0]']
#
#  conv2d_126 (Conv2D)            (None, 4, 4, 256)    16640       ['max_pooling2d_3[0][0]']
#
#  batch_normalization_129 (Batch  (None, 4, 4, 256)   1024        ['conv2d_129[0][0]']
#  Normalization)
#
#  batch_normalization_126 (Batch  (None, 4, 4, 256)   1024        ['conv2d_126[0][0]']
#  Normalization)
#
#  add_48 (Add)                   (None, 4, 4, 256)    0           ['batch_normalization_129[0][0]',
#                                                                   'batch_normalization_126[0][0]']
#
#  activation_118 (Activation)    (None, 4, 4, 256)    0           ['add_48[0][0]']
#
#  conv2d_130 (Conv2D)            (None, 4, 4, 64)     16448       ['activation_118[0][0]']
#
#  batch_normalization_130 (Batch  (None, 4, 4, 64)    256         ['conv2d_130[0][0]']
#  Normalization)
#
#  activation_119 (Activation)    (None, 4, 4, 64)     0           ['batch_normalization_130[0][0]']
#
#  conv2d_131 (Conv2D)            (None, 4, 4, 64)     36928       ['activation_119[0][0]']
#
#  batch_normalization_131 (Batch  (None, 4, 4, 64)    256         ['conv2d_131[0][0]']
#  Normalization)
#
#  activation_120 (Activation)    (None, 4, 4, 64)     0           ['batch_normalization_131[0][0]']
#
# ...
#
#  activation_145 (Activation)    (None, 1, 1, 1024)   0           ['add_57[0][0]']
#
#  conv2d_159 (Conv2D)            (None, 1, 1, 256)    262400      ['activation_145[0][0]']
#
#  batch_normalization_159 (Batch  (None, 1, 1, 256)   1024        ['conv2d_159[0][0]']
#  Normalization)
#
#  activation_146 (Activation)    (None, 1, 1, 256)    0           ['batch_normalization_159[0][0]']
#
#  conv2d_160 (Conv2D)            (None, 1, 1, 256)    590080      ['activation_146[0][0]']
#
#  batch_normalization_160 (Batch  (None, 1, 1, 256)   1024        ['conv2d_160[0][0]']
#  Normalization)
#
#  activation_147 (Activation)    (None, 1, 1, 256)    0           ['batch_normalization_160[0][0]']
#
#  conv2d_161 (Conv2D)            (None, 1, 1, 1024)   263168      ['activation_147[0][0]']
#
#  batch_normalization_161 (Batch  (None, 1, 1, 1024)  4096        ['conv2d_161[0][0]']
#  Normalization)
#
#  add_58 (Add)                   (None, 1, 1, 1024)   0           ['batch_normalization_161[0][0]',
#                                                                   'activation_145[0][0]']
#
#  activation_148 (Activation)    (None, 1, 1, 1024)   0           ['add_58[0][0]']
#
#  conv2d_162 (Conv2D)            (None, 1, 1, 256)    262400      ['activation_148[0][0]']
#
#  batch_normalization_162 (Batch  (None, 1, 1, 256)   1024        ['conv2d_162[0][0]']
#  Normalization)
#
#  activation_149 (Activation)    (None, 1, 1, 256)    0           ['batch_normalization_162[0][0]']
#
#  conv2d_163 (Conv2D)            (None, 1, 1, 256)    590080      ['activation_149[0][0]']
#
#  batch_normalization_163 (Batch  (None, 1, 1, 256)   1024        ['conv2d_163[0][0]']
#  Normalization)
#
#  activation_150 (Activation)    (None, 1, 1, 256)    0           ['batch_normalization_163[0][0]']
#
#  conv2d_164 (Conv2D)            (None, 1, 1, 1024)   263168      ['activation_150[0][0]']
#
#  batch_normalization_164 (Batch  (None, 1, 1, 1024)  4096        ['conv2d_164[0][0]']
#  Normalization)
#
#  add_59 (Add)                   (None, 1, 1, 1024)   0           ['batch_normalization_164[0][0]',
#                                                                   'activation_148[0][0]']
#
#  activation_151 (Activation)    (None, 1, 1, 1024)   0           ['add_59[0][0]']
#
#  conv2d_165 (Conv2D)            (None, 1, 1, 256)    262400      ['activation_151[0][0]']
#
#  batch_normalization_165 (Batch  (None, 1, 1, 256)   1024        ['conv2d_165[0][0]']
#  Normalization)
#
#  activation_152 (Activation)    (None, 1, 1, 256)    0           ['batch_normalization_165[0][0]']
#
#  conv2d_166 (Conv2D)            (None, 1, 1, 256)    590080      ['activation_152[0][0]']
#
#  batch_normalization_166 (Batch  (None, 1, 1, 256)   1024        ['conv2d_166[0][0]']
#  Normalization)
#
#  activation_153 (Activation)    (None, 1, 1, 256)    0           ['batch_normalization_166[0][0]']
#
#  conv2d_167 (Conv2D)            (None, 1, 1, 1024)   263168      ['activation_153[0][0]']
#
#  batch_normalization_167 (Batch  (None, 1, 1, 1024)  4096        ['conv2d_167[0][0]']
#  Normalization)
#
#  add_60 (Add)                   (None, 1, 1, 1024)   0           ['batch_normalization_167[0][0]',
#                                                                   'activation_151[0][0]']
#
#  activation_154 (Activation)    (None, 1, 1, 1024)   0           ['add_60[0][0]']
#
#  conv2d_169 (Conv2D)            (None, 1, 1, 512)    524800      ['activation_154[0][0]']
#
#  batch_normalization_169 (Batch  (None, 1, 1, 512)   2048        ['conv2d_169[0][0]']
#  Normalization)
#
#  activation_155 (Activation)    (None, 1, 1, 512)    0           ['batch_normalization_169[0][0]']
#
#  conv2d_170 (Conv2D)            (None, 1, 1, 512)    2359808     ['activation_155[0][0]']
#
#  batch_normalization_170 (Batch  (None, 1, 1, 512)   2048        ['conv2d_170[0][0]']
#  Normalization)
#
#  activation_156 (Activation)    (None, 1, 1, 512)    0           ['batch_normalization_170[0][0]']
#
#  conv2d_171 (Conv2D)            (None, 1, 1, 2048)   1050624     ['activation_156[0][0]']
#
#  conv2d_168 (Conv2D)            (None, 1, 1, 2048)   2099200     ['activation_154[0][0]']
#
#  batch_normalization_171 (Batch  (None, 1, 1, 2048)  8192        ['conv2d_171[0][0]']
#  Normalization)
#
#  batch_normalization_168 (Batch  (None, 1, 1, 2048)  8192        ['conv2d_168[0][0]']
#  Normalization)
#
#  add_61 (Add)                   (None, 1, 1, 2048)   0           ['batch_normalization_171[0][0]',
#                                                                   'batch_normalization_168[0][0]']
#
#  activation_157 (Activation)    (None, 1, 1, 2048)   0           ['add_61[0][0]']
#
#  conv2d_172 (Conv2D)            (None, 1, 1, 512)    1049088     ['activation_157[0][0]']
#
#  batch_normalization_172 (Batch  (None, 1, 1, 512)   2048        ['conv2d_172[0][0]']
#  Normalization)
#
#  activation_158 (Activation)    (None, 1, 1, 512)    0           ['batch_normalization_172[0][0]']
#
#  conv2d_173 (Conv2D)            (None, 1, 1, 512)    2359808     ['activation_158[0][0]']
#
#  batch_normalization_173 (Batch  (None, 1, 1, 512)   2048        ['conv2d_173[0][0]']
#  Normalization)
#
#  activation_159 (Activation)    (None, 1, 1, 512)    0           ['batch_normalization_173[0][0]']
#
#  conv2d_174 (Conv2D)            (None, 1, 1, 2048)   1050624     ['activation_159[0][0]']
#
#  batch_normalization_174 (Batch  (None, 1, 1, 2048)  8192        ['conv2d_174[0][0]']
#  Normalization)
#
#  add_62 (Add)                   (None, 1, 1, 2048)   0           ['batch_normalization_174[0][0]',
#                                                                   'activation_157[0][0]']
#
#  activation_160 (Activation)    (None, 1, 1, 2048)   0           ['add_62[0][0]']
#
#  conv2d_175 (Conv2D)            (None, 1, 1, 512)    1049088     ['activation_160[0][0]']
#
#  batch_normalization_175 (Batch  (None, 1, 1, 512)   2048        ['conv2d_175[0][0]']
#  Normalization)
#
#  activation_161 (Activation)    (None, 1, 1, 512)    0           ['batch_normalization_175[0][0]']
#
#  conv2d_176 (Conv2D)            (None, 1, 1, 512)    2359808     ['activation_161[0][0]']
#
#  batch_normalization_176 (Batch  (None, 1, 1, 512)   2048        ['conv2d_176[0][0]']
#  Normalization)
#
#  activation_162 (Activation)    (None, 1, 1, 512)    0           ['batch_normalization_176[0][0]']
#
#  conv2d_177 (Conv2D)            (None, 1, 1, 2048)   1050624     ['activation_162[0][0]']
#
#  batch_normalization_177 (Batch  (None, 1, 1, 2048)  8192        ['conv2d_177[0][0]']
#  Normalization)
#
#  add_63 (Add)                   (None, 1, 1, 2048)   0           ['batch_normalization_177[0][0]',
#                                                                   'activation_160[0][0]']
#
#  activation_163 (Activation)    (None, 1, 1, 2048)   0           ['add_63[0][0]']
#
#  global_average_pooling2d_3 (Gl  (None, 2048)        0           ['activation_163[0][0]']
#  obalAveragePooling2D)
#
#  dense_3 (Dense)                (None, 10)           20490       ['global_average_pooling2d_3[0][0
#                                                                  ]']
#
# ==================================================================================================
# Total params: 23,608,202
# Trainable params: 23,555,082
# Non-trainable params: 53,120
# __________________________________________________________________________________________________

# %% [markdown]
# **3) 일반 네트워크(plain network) 만들기**
#
# 블록 코드 수정하기
#  ResNet의 핵심 아이디어는 skip connection과 residual network기 때문에, ResNet의 효과를 보여주기 위해서는 skip connection이 없는 일반 네트워크(plain net)가 필요합니다.

# %%
def build_plain_block(input_layer, 
                      num_cnn=3, 
                      channel=64, 
                      block_num=0, 
                      is_50=True):
    
    x = input_layer
    
    # plain-50
    if is_50:
        for i in range(num_cnn):
            if block_num > 0 and i == 0:
                x = conv_block(x, channel, (1,1), strides=2)
                x = conv_block(x, channel, (3,3))
                x = conv_block(x, channel*4, (1,1))
            else:
                x = conv_block(x, channel, (1,1))
                x = conv_block(x, channel, (3,3))
                x = conv_block(x, channel*4, (1,1))
    
    # plain-34
    else:
        for i in range(num_cnn):
            if block_num > 0 and i == 0:
                x = conv_block(x, channel, (3,3), strides=2)
                x = conv_block(x, channel, (3,3))
            else:
                x = conv_block(x, channel, (3,3))
                x = conv_block(x, channel, (3,3))

    return x

# %%
def build_plainnet(input_shape=(32,32,3), 
                   num_cnn_list=[3,4,6,3],
                   channel_list=[64,128,256,512],
                   num_classes=10,
                   is_50=True, 
                   activation='softmax',
                   name='Plain_50'):
    
    assert len(num_cnn_list) == len(channel_list)
    
    input_layer = keras.layers.Input(shape=input_shape)
    
    # first layer
    x = conv_block(input_layer, 64, (7,7), strides=2)
    x = keras.layers.MaxPool2D(pool_size=(2,2), strides=2)(x)
    
    # config list들의 길이만큼 반복해서 plain block 블록을 생성합니다.
    for block_num, (num_cnn, channel) in enumerate(zip(num_cnn_list, channel_list)):
        x = build_plain_block(x, 
                              num_cnn=num_cnn, 
                              channel=channel,
                              block_num=block_num,
                              is_50=is_50)
    
    x = keras.layers.GlobalAveragePooling2D()(x)
    x = keras.layers.Dense(num_classes, 
                           activation=activation,
                           kernel_initializer='he_normal'
                          )(x)
    
    model = keras.Model(inputs=input_layer, outputs=x, name=name)
    
    return model

# %% [markdown]
# **4) ResNet-50 vs Plain-50 또는 ResNet-34 vs Plain-34**
#
# **Ablation Study**
#  ResNet은 많은 레이어와 Pooling을 거치므로 CIFAR-10에서는 오버피팅(overfitting)으로 잘 동작하지 않을 수 있습니다. 레이어가 많고 학습해야 할 변수(parameter)가 많은 데 비해, 데이터 수가 많지 않기 때문. 224x224 픽셀 크기의 데이터셋을 찾아서 실험

# %%
BATCH_SIZE = 32
EPOCH = 5

# %%
ds_train = apply_normalize_on_dataset(ds_train, batch_size=BATCH_SIZE)
ds_test = apply_normalize_on_dataset(ds_test, batch_size=BATCH_SIZE)

# %%
plain_34 = build_plainnet(input_shape=(224, 224, 3), 
                          num_classes=1, 
                          is_50=False, 
                          activation='sigmoid',
                          name='Plain_34')

plain_34.compile(
    loss='binary_crossentropy',
    optimizer=tf.keras.optimizers.Adam(lr=0.001),
    metrics=['accuracy'],
)

history_plain_34 = plain_34.fit(
    ds_train,
    steps_per_epoch=int(ds_info.splits['train[:80%]'].num_examples/BATCH_SIZE),
    validation_steps=int(ds_info.splits['train[80%:]'].num_examples/BATCH_SIZE),
    epochs=EPOCH,
    validation_data=ds_test,
    verbose=1,
    use_multiprocessing=True,
)
# Out:
# Epoch 1/5
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# 581/581 [==============================] - 10215s 18s/step - loss: 1.6939 - accuracy: 0.5265 - val_loss: 1.3677 - val_accuracy: 0.4985
# Epoch 2/5
# 581/581 [==============================] - ETA: 0s - loss: 1.1091 - accuracy: 0.5643

# %%
resnet_34 = build_resnet(input_shape=(224, 224, 3),                                
                               num_classes=1, 
                               is_50=False, 
                               activation='sigmoid', 
                               name='ResNet_34')

resnet_34.compile(
    loss='binary_crossentropy',
    optimizer=tf.keras.optimizers.Adam(lr=0.001),
    metrics=['accuracy'],
)

history_resnet_34 = resnet_34.fit(
    ds_train,
    steps_per_epoch=int(ds_info.splits['train[:80%]'].num_examples/BATCH_SIZE),
    validation_steps=int(ds_info.splits['train[80%:]'].num_examples/BATCH_SIZE),
    epochs=EPOCH,
    validation_data=ds_test,
    verbose=1,
    use_multiprocessing=True
)
# Out:
# Epoch 1/5
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# 581/581 [==============================] - 86s 127ms/step - loss: 1.9622 - accuracy: 0.6205 - val_loss: 1.5665 - val_accuracy: 0.6145
# Epoch 2/5
# 581/581 [==============================] - 73s 126ms/step - loss: 1.1210 - accuracy: 0.7180 - val_loss: 6.3938 - val_accuracy: 0.4905
# Epoch 3/5
# 581/581 [==============================] - 73s 126ms/step - loss: 0.7774 - accuracy: 0.7731 - val_loss: 0.9692 - val_accuracy: 0.6028
# Epoch 4/5
# 581/581 [==============================] - 73s 127ms/step - loss: 0.6041 - accuracy: 0.8222 - val_loss: 0.9482 - val_accuracy: 0.7004
# Epoch 5/5
# 581/581 [==============================] - 73s 126ms/step - loss: 0.5096 - accuracy: 0.8505 - val_loss: 0.8021 - val_accuracy: 0.7263

# %%
plain_50 = build_plainnet(input_shape=(224, 224, 3), 
                          num_classes=1, 
                          is_50=True,
                          activation='sigmoid')

plain_50.compile(
    loss='binary_crossentropy',
    optimizer=tf.keras.optimizers.Adam(lr=0.001),
    metrics=['accuracy'],
)

history_plain_50 = plain_50.fit(
    ds_train,
    steps_per_epoch=int(ds_info.splits['train[:80%]'].num_examples/BATCH_SIZE),
    validation_steps=int(ds_info.splits['train[80%:]'].num_examples/BATCH_SIZE),
    epochs=EPOCH,
    validation_data=ds_test,
    verbose=1,
    use_multiprocessing=True,
)
# Out:
# Epoch 1/5
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# 581/581 [==============================] - 114s 172ms/step - loss: 3.6032 - accuracy: 0.5083 - val_loss: 2.6730 - val_accuracy: 0.5063
# Epoch 2/5
# 581/581 [==============================] - 98s 169ms/step - loss: 2.1764 - accuracy: 0.5381 - val_loss: 1.8668 - val_accuracy: 0.5058
# Epoch 3/5
# 581/581 [==============================] - 99s 170ms/step - loss: 1.7052 - accuracy: 0.5092 - val_loss: 1.7245 - val_accuracy: 0.4896
# Epoch 4/5
# 581/581 [==============================] - 99s 170ms/step - loss: 1.4694 - accuracy: 0.5003 - val_loss: 1.3918 - val_accuracy: 0.4806
# Epoch 5/5
# 581/581 [==============================] - 99s 170ms/step - loss: 1.3073 - accuracy: 0.5160 - val_loss: 110252.2344 - val_accuracy: 0.5167

# %%
resnet_50 = build_resnet(input_shape=(224, 224, 3), 
                         num_classes=1, 
                         is_50=True,
                         activation='sigmoid')

resnet_50.compile(
    loss='binary_crossentropy',
    optimizer=tf.keras.optimizers.Adam(lr=0.001),
    metrics=['accuracy'],
)

history_resnet_50 = resnet_50.fit(
    ds_train,
    steps_per_epoch=int(ds_info.splits['train[:80%]'].num_examples/BATCH_SIZE),
    validation_steps=int(ds_info.splits['train[80%:]'].num_examples/BATCH_SIZE),
    epochs=EPOCH,
    validation_data=ds_test,
    verbose=1,
    use_multiprocessing=True,
)
# Out:
# Epoch 1/5
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# 581/581 [==============================] - 77s 108ms/step - loss: 5.1514 - accuracy: 0.6358 - val_loss: 4.1552 - val_accuracy: 0.6532
# Epoch 2/5
# 581/581 [==============================] - 62s 106ms/step - loss: 3.1846 - accuracy: 0.7367 - val_loss: 2.7781 - val_accuracy: 0.6093
# Epoch 3/5
# 581/581 [==============================] - 62s 106ms/step - loss: 2.0865 - accuracy: 0.7835 - val_loss: 1.8160 - val_accuracy: 0.7608
# Epoch 4/5
# 581/581 [==============================] - 62s 107ms/step - loss: 1.4936 - accuracy: 0.8208 - val_loss: 1.7289 - val_accuracy: 0.6550
# Epoch 5/5
# 581/581 [==============================] - 62s 107ms/step - loss: 1.1430 - accuracy: 0.8542 - val_loss: 1.1260 - val_accuracy: 0.8201

# %% [markdown]
# **시각화**
# 학습을 통해 만들어진 history를 matplotlib로 시각화하여 두 모델의 검증 정확도(validation accuracy)와 검증 손실(validation loss)이 어떻게 다른지 살펴봅시다.

# %%
plt.figure(figsize=(16,6))
plt.subplot(1,2,1)
plt.plot(history_resnet_34.history['loss'],'r')
plt.plot(history_plain_34.history['loss'],'b')
plt.title('Model training loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['ResNet-34', 'Plain-34'], loc='upper left')

plt.subplot(1, 2, 2)
plt.plot(history_resnet_34.history['val_accuracy'], 'r')
plt.plot(history_plain_34.history['val_accuracy'], 'b')
plt.title('Model validation accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['ResNet-34', 'Plain-34'], loc='upper left')
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(16,6))
plt.subplot(1,2,1)
plt.plot(history_resnet_50.history['loss'],'r')
plt.plot(history_plain_50.history['loss'],'b')
plt.title('Model training loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['ResNet-50', 'Plain-50'], loc='upper left')

plt.subplot(1, 2, 2)
plt.plot(history_resnet_50.history['val_accuracy'], 'r')
plt.plot(history_plain_50.history['val_accuracy'], 'b')
plt.title('Model validation accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['ResNet-50', 'Plain-50'], loc='upper left')
plt.show()

# %% [markdown]
# ### trial and error
#
# epochs를 5로 잡은 것치곤 만족스러운 결과가 나왔다. 비록 초반에 GPU 설정도 안 하고 시간 보내고 이후엔 충전기 연결을 하지 않은 채로 돌려서 배터리가 미친 속도로 다는 경험을 했지만 그만큼 다음번엔 더 안정된 상태에서 실행할 수 있을 것 같다. 그동안 대부분의 모델을 경험했다 생각하는데 구현은 또 다른 문제인 것 같다. 논문을 자세히 읽고 하나하나 파악은 했지만 직접 코드를 쓴다는 건 더 능력이 필요한 영역 같다. 진짜 내 프로젝트를 해볼 날이 기대된다. 그때는 오로지 내 실력과 동료들의 실력으로 구현한 멋진 코드였으면 좋겠고 올해 최고의 배움이 될 것 같다.
